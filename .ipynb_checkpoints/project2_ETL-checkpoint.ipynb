# %%
import pandas as pd
import numpy as np
import csv
import os
import sqlite3
import sqlalchemy
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
review_file = "google-play-store-apps/googleplaystore_user_reviews.csv"
review_df = pd.read_csv(review_file)
review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
app_file = "google-play-store-apps/googleplaystore.csv"
app_df = pd.read_csv(app_file)
app_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
merge_df = pd.merge(app_df, review_df, on="App")
merge_df.head()
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# 2       2.0.0  4.0.3 and up
# 3       2.0.0  4.0.3 and up
# 4       2.0.0  4.0.3 and up
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# 1                                         It bad >:(  Negative
# 2                                               like   Neutral
# 3                                                NaN       NaN
# 4                           I love colors inspyering  Positive
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0              -0.250                1.000000
# 1              -0.725                0.833333
# 2               0.000                0.000000
# 3                 NaN                     NaN
# 4               0.500                0.600000

# %%
drop_columns = ["Size",'Content Rating','Genres','Last Updated','Translated_Review','Sentiment_Polarity','Sentiment_Subjectivity']
clean_df = merge_df.drop(drop_columns, axis=1)
clean_df.head()
# Out:
#                    App        Category  Rating Reviews  Installs  Type Price  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  500,000+  Free     0
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  500,000+  Free     0
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  500,000+  Free     0
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  500,000+  Free     0
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  500,000+  Free     0
#
#   Current Ver   Android Ver Sentiment
# 0       2.0.0  4.0.3 and up  Negative
# 1       2.0.0  4.0.3 and up  Negative
# 2       2.0.0  4.0.3 and up   Neutral
# 3       2.0.0  4.0.3 and up       NaN
# 4       2.0.0  4.0.3 and up  Positive

# %%
clean_df = clean_df.dropna()
clean_df.count()
# Out:
# App            72576
# Category       72576
# Rating         72576
# Reviews        72576
# Installs       72576
# Type           72576
# Price          72576
# Current Ver    72576
# Android Ver    72576
# Sentiment      72576
# dtype: int64

# %%
import mysql.connector

database= mysql.connector.connect(
  host="cwru-data-project02.ciuevunbeloh.us-east-2.rds.amazonaws.com",
  user ="group08",
  passwd ="jJGyvjMxKcAX5WfU"
)

mycursor = database.cursor()

mycursor.execute("CREATE DATABASE group08")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     391                                raw=raw, buffered=buffered,
# --> 392                                raw_as_string=raw_as_string)
#     393         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Can't create database 'google'; database exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-7-721ab2d18639> in <module>()
#       9 mycursor = database.cursor()
#      10
# ---> 11 mycursor.execute("CREATE DATABASE google")
#      12
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     262             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     263                                          buffered=self._buffered,
# --> 264                                          raw_as_string=self._raw_as_string)
#     265         except MySQLInterfaceError as exc:
#     266             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     393         except MySQLInterfaceError as exc:
#     394             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 395                                              sqlstate=exc.sqlstate)
#     396         except AttributeError:
#     397             if self._unix_socket:
#
# DatabaseError: 1007 (HY000): Can't create database 'google'; database exists

# %%
engine = create_engine("mysql://group08:jJGyvjMxKcAX5WfU@cwru-data-project02.ciuevunbeloh.us-east-2.rds.amazonaws.com/group08")

# %%
conn = engine.connect()

# %%
row_count = clean_df["App"].count()
print(row_count)

half = int(row_count/2)
third = int(row_count//3)
mod = row_count%14
print(mod)

fourteen = int(row_count/14)
print(fourteen)
# Out:
# 72576
# 0
# 5184

# %%
testing= clean_df.iloc[:fourteen,:]

# %%
clean_df.iloc[152,:]
# Out:
# App            Garden Coloring Book
# Category             ART_AND_DESIGN
# Rating                          4.4
# Reviews                       13791
# Installs                 1,000,000+
# Type                           Free
# Price                             0
# Current Ver                   2.9.2
# Android Ver              3.0 and up
# Sentiment                   Neutral
# Name: 185, dtype: object

# %%
data = engine.execute("SELECT * FROM test3 LIMIT 5")
for x in data:
    print(x)
# Out:
# (0, 'Coloring book moana', 'ART_AND_DESIGN', 3.9, '967', '500,000+', 'Free', '0', '2.0.0', '4.0.3 and up', 'Negative')
# (1, 'Coloring book moana', 'ART_AND_DESIGN', 3.9, '967', '500,000+', 'Free', '0', '2.0.0', '4.0.3 and up', 'Negative')
# (2, 'Coloring book moana', 'ART_AND_DESIGN', 3.9, '967', '500,000+', 'Free', '0', '2.0.0', '4.0.3 and up', 'Neutral')
# (4, 'Coloring book moana', 'ART_AND_DESIGN', 3.9, '967', '500,000+', 'Free', '0', '2.0.0', '4.0.3 and up', 'Positive')
# (5, 'Coloring book moana', 'ART_AND_DESIGN', 3.9, '967', '500,000+', 'Free', '0', '2.0.0', '4.0.3 and up', 'Negative')

# %%
for x in range(row_count):
    try:
        attempt = clean_df.iloc[x:x+1,:]
        attempt.to_sql("data", conn, if_exists="append")
        print("go go data dump " + str(x))
    except:
        print("skipping... " + str(x))
# Out:
# go go data dump 0
# go go data dump 1
# go go data dump 2
# go go data dump 3
# go go data dump 4
# go go data dump 5
# go go data dump 6
# go go data dump 7
# go go data dump 8
# go go data dump 9
# go go data dump 10
# go go data dump 11
# go go data dump 12
# go go data dump 13
# go go data dump 14
# go go data dump 15
# go go data dump 16
# go go data dump 17
# go go data dump 18
# go go data dump 19
# go go data dump 20
# go go data dump 21
# go go data dump 22
# go go data dump 23
# go go data dump 24
# go go data dump 25
# go go data dump 26
# go go data dump 27
# go go data dump 28
# go go data dump 29
# go go data dump 30
# go go data dump 31
# go go data dump 32
# go go data dump 33
# go go data dump 34
# go go data dump 35
# go go data dump 36
# go go data dump 37
# skipping... 38
# go go data dump 39
# go go data dump 40
# go go data dump 41
# go go data dump 42
# go go data dump 43
# go go data dump 44
# go go data dump 45
# go go data dump 46
# go go data dump 47
# go go data dump 48
# go go data dump 49
# go go data dump 50
# go go data dump 51
# go go data dump 52
# go go data dump 53
# go go data dump 54
# go go data dump 55
# go go data dump 56
# go go data dump 57
# go go data dump 58
# go go data dump 59
# go go data dump 60
# go go data dump 61
# go go data dump 62
# go go data dump 63
# go go data dump 64
# go go data dump 65
# go go data dump 66
# go go data dump 67
# go go data dump 68
# go go data dump 69
# go go data dump 70
# go go data dump 71
# go go data dump 72
# go go data dump 73
# go go data dump 74
# go go data dump 75
# go go data dump 76
# go go data dump 77
# go go data dump 78
# go go data dump 79
# go go data dump 80
# go go data dump 81
# go go data dump 82
# go go data dump 83
# go go data dump 84
# go go data dump 85
# go go data dump 86
# go go data dump 87
# go go data dump 88
# go go data dump 89
# go go data dump 90
# go go data dump 91
# go go data dump 92
# go go data dump 93
# go go data dump 94
# go go data dump 95
# go go data dump 96
# go go data dump 97
# go go data dump 98
# go go data dump 99
# go go data dump 100
# go go data dump 101
# go go data dump 102
# go go data dump 103
# go go data dump 104
# go go data dump 105
# go go data dump 106
# go go data dump 107
# go go data dump 108
# go go data dump 109
# go go data dump 110
# go go data dump 111
# go go data dump 112
# go go data dump 113
# go go data dump 114
# go go data dump 115
# go go data dump 116
# go go data dump 117
# go go data dump 118
# go go data dump 119
# go go data dump 120
# go go data dump 121
# go go data dump 122
# go go data dump 123
# go go data dump 124
# go go data dump 125
# go go data dump 126
# go go data dump 127
# go go data dump 128
# go go data dump 129
# go go data dump 130
# go go data dump 131
# go go data dump 132
# go go data dump 133
# go go data dump 134
# go go data dump 135
# go go data dump 136
# go go data dump 137
# go go data dump 138
# go go data dump 139
# go go data dump 140
# go go data dump 141
# go go data dump 142
# go go data dump 143
# go go data dump 144
# go go data dump 145
# go go data dump 146
# go go data dump 147
# go go data dump 148
# go go data dump 149
# go go data dump 150
# go go data dump 151
# go go data dump 152
# go go data dump 153
# go go data dump 154
# go go data dump 155
# go go data dump 156
# go go data dump 157
# go go data dump 158
# go go data dump 159
# go go data dump 160
# go go data dump 161
# go go data dump 162
# go go data dump 163
# go go data dump 164
# go go data dump 165
# go go data dump 166
# go go data dump 167
# go go data dump 168
# go go data dump 169
# go go data dump 170
# go go data dump 171
# go go data dump 172
# go go data dump 173
# go go data dump 174
# go go data dump 175
# go go data dump 176
# go go data dump 177
# go go data dump 178
# go go data dump 179
# go go data dump 180
# go go data dump 181
# go go data dump 182
# go go data dump 183
# go go data dump 184
# go go data dump 185
# go go data dump 186
# go go data dump 187
# go go data dump 188
# go go data dump 189
# go go data dump 190
# go go data dump 191
# go go data dump 192
# go go data dump 193
# go go data dump 194
# go go data dump 195
# go go data dump 196
# go go data dump 197
# go go data dump 198
# go go data dump 199
# go go data dump 200
# go go data dump 201
# go go data dump 202
# go go data dump 203
# go go data dump 204
# go go data dump 205
# go go data dump 206
# go go data dump 207
# go go data dump 208
# go go data dump 209
# go go data dump 210
# go go data dump 211
# go go data dump 212
# go go data dump 213
# go go data dump 214
# go go data dump 215
# go go data dump 216
# go go data dump 217
# go go data dump 218
# go go data dump 219
# go go data dump 220
# go go data dump 221
# go go data dump 222
# go go data dump 223
# go go data dump 224
# go go data dump 225
# go go data dump 226
# go go data dump 227
# go go data dump 228
# go go data dump 229
# go go data dump 230
# go go data dump 231
# go go data dump 232
# go go data dump 233
# go go data dump 234
# go go data dump 235
# go go data dump 236
# go go data dump 237
# go go data dump 238
# go go data dump 239
# go go data dump 240
# go go data dump 241
# go go data dump 242
# go go data dump 243
# go go data dump 244
# go go data dump 245
# go go data dump 246
# go go data dump 247
# go go data dump 248
# go go data dump 249
# go go data dump 250
# go go data dump 251
# go go data dump 252
# go go data dump 253
# go go data dump 254
# go go data dump 255
# go go data dump 256
# go go data dump 257
# go go data dump 258
# go go data dump 259
# go go data dump 260
# go go data dump 261
# go go data dump 262
# go go data dump 263
# go go data dump 264
# go go data dump 265
# go go data dump 266
# go go data dump 267
# go go data dump 268
# go go data dump 269
# go go data dump 270
# go go data dump 271
# go go data dump 272
# go go data dump 273
# go go data dump 274
# go go data dump 275
# go go data dump 276
# go go data dump 277
# go go data dump 278
# go go data dump 279
# go go data dump 280
# go go data dump 281
# go go data dump 282
# go go data dump 283
# go go data dump 284
# go go data dump 285
# go go data dump 286
# go go data dump 287
# go go data dump 288
# go go data dump 289
# go go data dump 290
# go go data dump 291
# go go data dump 292
# go go data dump 293
# go go data dump 294
# go go data dump 295
# go go data dump 296
# go go data dump 297
# go go data dump 298
# go go data dump 299
# go go data dump 300
# go go data dump 301
# go go data dump 302
# go go data dump 303
# go go data dump 304
# go go data dump 305
# go go data dump 306
# go go data dump 307
# go go data dump 308
# go go data dump 309
# go go data dump 310
# go go data dump 311
# go go data dump 312
# go go data dump 313
# go go data dump 314
# go go data dump 315
# go go data dump 316
# go go data dump 317
# go go data dump 318
# go go data dump 319
# go go data dump 320
# go go data dump 321
# go go data dump 322
# go go data dump 323
# go go data dump 324
# go go data dump 325
# go go data dump 326
# go go data dump 327
# go go data dump 328
# go go data dump 329
# go go data dump 330
# go go data dump 331
# go go data dump 332
# go go data dump 333
# go go data dump 334
# go go data dump 335
# go go data dump 336
# go go data dump 337
# go go data dump 338
# go go data dump 339
# go go data dump 340
# go go data dump 341
# go go data dump 342
# go go data dump 343
# go go data dump 344
# go go data dump 345
# go go data dump 346
# go go data dump 347
# go go data dump 348
# go go data dump 349
# go go data dump 350
# go go data dump 351
# go go data dump 352
# go go data dump 353
# go go data dump 354
# go go data dump 355
# go go data dump 356
# go go data dump 357
# go go data dump 358
# go go data dump 359
# go go data dump 360
# go go data dump 361
# go go data dump 362
# go go data dump 363
# go go data dump 364
# go go data dump 365
# go go data dump 366
# go go data dump 367
# go go data dump 368
# go go data dump 369
# go go data dump 370
# go go data dump 371
# go go data dump 372
# go go data dump 373
# go go data dump 374
# go go data dump 375
# go go data dump 376
# go go data dump 377
# go go data dump 378
# go go data dump 379
# go go data dump 380
# go go data dump 381
# go go data dump 382
# go go data dump 383
# go go data dump 384
# go go data dump 385
# go go data dump 386
# go go data dump 387
# go go data dump 388
# go go data dump 389
# go go data dump 390
# go go data dump 391
# go go data dump 392
# go go data dump 393
# go go data dump 394
# go go data dump 395
# go go data dump 396
# go go data dump 397
# go go data dump 398
# go go data dump 399
# go go data dump 400
# go go data dump 401
# go go data dump 402
# go go data dump 403
# go go data dump 404
# go go data dump 405
# go go data dump 406
# go go data dump 407
# go go data dump 408
# go go data dump 409
# go go data dump 410
# go go data dump 411
# go go data dump 412
# go go data dump 413
# go go data dump 414
# go go data dump 415
# go go data dump 416
# go go data dump 417
# go go data dump 418
# go go data dump 419
# go go data dump 420
# go go data dump 421
# go go data dump 422
# go go data dump 423
# go go data dump 424
# go go data dump 425
# go go data dump 426
# go go data dump 427
# go go data dump 428
# go go data dump 429
# go go data dump 430
# go go data dump 431
# go go data dump 432
# go go data dump 433
# go go data dump 434
# go go data dump 435
# go go data dump 436
# go go data dump 437
# go go data dump 438
# go go data dump 439
# go go data dump 440
# go go data dump 441
# go go data dump 442
# go go data dump 443
# go go data dump 444
# go go data dump 445
# go go data dump 446
# go go data dump 447
# go go data dump 448
# go go data dump 449
# go go data dump 450
# go go data dump 451
# go go data dump 452
# go go data dump 453
# go go data dump 454
# go go data dump 455
# go go data dump 456
# go go data dump 457
# go go data dump 458
# go go data dump 459
# go go data dump 460
# go go data dump 461
# go go data dump 462
# go go data dump 463
# go go data dump 464
# go go data dump 465
# go go data dump 466
# go go data dump 467
# go go data dump 468
# go go data dump 469
# go go data dump 470
# go go data dump 471
# go go data dump 472
# go go data dump 473
# go go data dump 474
# go go data dump 475
# go go data dump 476
# go go data dump 477
# go go data dump 478
# go go data dump 479
# go go data dump 480
# go go data dump 481
# go go data dump 482
# go go data dump 483
# go go data dump 484
# go go data dump 485
# go go data dump 486
# go go data dump 487
# go go data dump 488
# go go data dump 489
# go go data dump 490
# go go data dump 491
# go go data dump 492
# go go data dump 493
# go go data dump 494
# go go data dump 495
# go go data dump 496
# go go data dump 497
# go go data dump 498
# go go data dump 499
# go go data dump 500
# go go data dump 501
# go go data dump 502
# go go data dump 503
# go go data dump 504
# go go data dump 505
# go go data dump 506
# go go data dump 507
# go go data dump 508
# go go data dump 509
# go go data dump 510
# go go data dump 511
# go go data dump 512
# go go data dump 513
# go go data dump 514
# go go data dump 515
# go go data dump 516
# go go data dump 517
# go go data dump 518
# go go data dump 519
# go go data dump 520
# go go data dump 521
# go go data dump 522
# go go data dump 523
# go go data dump 524
# go go data dump 525
# go go data dump 526
# go go data dump 527
# go go data dump 528
# go go data dump 529
# go go data dump 530
# go go data dump 531
# go go data dump 532
# go go data dump 533
# go go data dump 534
# go go data dump 535
# go go data dump 536
# go go data dump 537
# go go data dump 538
# go go data dump 539
# go go data dump 540
# go go data dump 541
# go go data dump 542
# go go data dump 543
# go go data dump 544
# go go data dump 545
# go go data dump 546
# go go data dump 547
# go go data dump 548
# go go data dump 549
# go go data dump 550
# go go data dump 551
# go go data dump 552
# go go data dump 553
# go go data dump 554
# go go data dump 555
# go go data dump 556
# go go data dump 557
# go go data dump 558
# go go data dump 559
# go go data dump 560
# go go data dump 561
# go go data dump 562
# go go data dump 563
# go go data dump 564
# go go data dump 565
# go go data dump 566
# go go data dump 567
# go go data dump 568
# go go data dump 569
# go go data dump 570
# go go data dump 571
# go go data dump 572
# go go data dump 573
# go go data dump 574
# go go data dump 575
# go go data dump 576
# go go data dump 577
# go go data dump 578
# go go data dump 579
# go go data dump 580
# go go data dump 581
# go go data dump 582
# go go data dump 583
# go go data dump 584
# go go data dump 585
# go go data dump 586
# go go data dump 587
# go go data dump 588
# go go data dump 589
# go go data dump 590
# go go data dump 591
# go go data dump 592
# go go data dump 593
# go go data dump 594
# go go data dump 595
# go go data dump 596
# go go data dump 597
# go go data dump 598
# go go data dump 599
# go go data dump 600
# go go data dump 601
# go go data dump 602
# go go data dump 603
# go go data dump 604
# go go data dump 605
# go go data dump 606
# go go data dump 607
# go go data dump 608
# go go data dump 609
# go go data dump 610
# go go data dump 611
# go go data dump 612
# go go data dump 613
# go go data dump 614
# go go data dump 615
# go go data dump 616
# go go data dump 617
# go go data dump 618
# go go data dump 619
# go go data dump 620
# go go data dump 621
# go go data dump 622
# go go data dump 623
# go go data dump 624
# go go data dump 625
# go go data dump 626
# go go data dump 627
# go go data dump 628
# go go data dump 629
# go go data dump 630
# go go data dump 631
# go go data dump 632
# go go data dump 633
# go go data dump 634
# go go data dump 635
# go go data dump 636
# go go data dump 637
# go go data dump 638
# go go data dump 639
# go go data dump 640
# go go data dump 641
# go go data dump 642
# go go data dump 643
# go go data dump 644
# go go data dump 645
# go go data dump 646
# go go data dump 647
# go go data dump 648
# go go data dump 649
# go go data dump 650
# go go data dump 651
# go go data dump 652
# go go data dump 653
# go go data dump 654
# go go data dump 655
# go go data dump 656
# go go data dump 657
# go go data dump 658
# go go data dump 659
# go go data dump 660
# go go data dump 661
# go go data dump 662
# go go data dump 663
# go go data dump 664
# go go data dump 665
# go go data dump 666
# go go data dump 667
# go go data dump 668
# go go data dump 669
# go go data dump 670
# go go data dump 671
# go go data dump 672
# go go data dump 673
# go go data dump 674
# go go data dump 675
# go go data dump 676
# go go data dump 677
# go go data dump 678
# go go data dump 679
# go go data dump 680
# go go data dump 681
# go go data dump 682
# go go data dump 683
# go go data dump 684
# go go data dump 685
# go go data dump 686
# go go data dump 687
# go go data dump 688
# go go data dump 689
# go go data dump 690
# go go data dump 691
# go go data dump 692
# go go data dump 693
# go go data dump 694
# go go data dump 695
# go go data dump 696
# go go data dump 697
# go go data dump 698
# go go data dump 699
# go go data dump 700
# go go data dump 701
# go go data dump 702
# go go data dump 703
# go go data dump 704
# go go data dump 705
# go go data dump 706
# go go data dump 707
# go go data dump 708
# go go data dump 709
# go go data dump 710
# go go data dump 711
# go go data dump 712
# go go data dump 713
# go go data dump 714
# go go data dump 715
# go go data dump 716
# go go data dump 717
# go go data dump 718
# go go data dump 719
# go go data dump 720
# go go data dump 721
# go go data dump 722
# go go data dump 723
# go go data dump 724
# go go data dump 725
# go go data dump 726
# go go data dump 727
# go go data dump 728
# go go data dump 729
# go go data dump 730
# go go data dump 731
# go go data dump 732
# go go data dump 733
# go go data dump 734
# go go data dump 735
# go go data dump 736
# go go data dump 737
# go go data dump 738
# go go data dump 739
# go go data dump 740
# go go data dump 741
# go go data dump 742
# go go data dump 743
# go go data dump 744
# go go data dump 745
# go go data dump 746
# go go data dump 747
# go go data dump 748
# go go data dump 749
# go go data dump 750
# go go data dump 751
# go go data dump 752
# go go data dump 753
# go go data dump 754
# go go data dump 755
# go go data dump 756
# go go data dump 757
# go go data dump 758
# go go data dump 759
# go go data dump 760
# go go data dump 761
# go go data dump 762
# go go data dump 763
# go go data dump 764
# go go data dump 765
# go go data dump 766
# go go data dump 767
# go go data dump 768
# go go data dump 769
# go go data dump 770
# go go data dump 771
# go go data dump 772
# go go data dump 773
# go go data dump 774
# go go data dump 775
# go go data dump 776
# go go data dump 777
# go go data dump 778
# go go data dump 779
# go go data dump 780
# go go data dump 781
# go go data dump 782
# go go data dump 783
# go go data dump 784
# go go data dump 785
# go go data dump 786
# go go data dump 787
# go go data dump 788
# go go data dump 789
# go go data dump 790
# go go data dump 791
# go go data dump 792
# go go data dump 793
# go go data dump 794
# go go data dump 795
# go go data dump 796
# go go data dump 797
# go go data dump 798
# go go data dump 799
# go go data dump 800
# go go data dump 801
# go go data dump 802
# go go data dump 803
# go go data dump 804
# go go data dump 805
# go go data dump 806
# go go data dump 807
# go go data dump 808
# go go data dump 809
# go go data dump 810
# go go data dump 811
# go go data dump 812
# go go data dump 813
# go go data dump 814
# go go data dump 815
# go go data dump 816
# go go data dump 817
# go go data dump 818
# go go data dump 819
# go go data dump 820
# go go data dump 821
# go go data dump 822
# go go data dump 823
# go go data dump 824
# go go data dump 825
# go go data dump 826
# go go data dump 827
# go go data dump 828
# go go data dump 829
# go go data dump 830
# go go data dump 831
# go go data dump 832
# go go data dump 833
# go go data dump 834
# go go data dump 835
# go go data dump 836
# go go data dump 837
# go go data dump 838
# go go data dump 839
# go go data dump 840
# go go data dump 841
# go go data dump 842
# go go data dump 843
# go go data dump 844
# go go data dump 845
# go go data dump 846
# go go data dump 847
# go go data dump 848
# go go data dump 849
# go go data dump 850
# go go data dump 851
# go go data dump 852
# go go data dump 853
# go go data dump 854
# go go data dump 855
# go go data dump 856
# go go data dump 857
# go go data dump 858
# go go data dump 859
# go go data dump 860
# go go data dump 861
# go go data dump 862
# go go data dump 863
# go go data dump 864
# go go data dump 865
# go go data dump 866
# go go data dump 867
# go go data dump 868
# go go data dump 869
# go go data dump 870
# go go data dump 871
# go go data dump 872
# go go data dump 873
# go go data dump 874
# go go data dump 875
# go go data dump 876
# go go data dump 877
# go go data dump 878
# go go data dump 879
# go go data dump 880
# go go data dump 881
# go go data dump 882
# go go data dump 883
# go go data dump 884
# go go data dump 885
# go go data dump 886
# go go data dump 887
# go go data dump 888
# go go data dump 889
# go go data dump 890
# go go data dump 891
# go go data dump 892
# go go data dump 893
# go go data dump 894
# go go data dump 895
# go go data dump 896
# go go data dump 897
# go go data dump 898
# go go data dump 899
# go go data dump 900
# go go data dump 901
# go go data dump 902
# go go data dump 903
# go go data dump 904
# go go data dump 905
# go go data dump 906
# go go data dump 907
# go go data dump 908
# go go data dump 909
# go go data dump 910
# go go data dump 911
# go go data dump 912
# go go data dump 913
# go go data dump 914
# go go data dump 915
# go go data dump 916
# go go data dump 917
# go go data dump 918
# go go data dump 919
# go go data dump 920
# go go data dump 921
# go go data dump 922
# go go data dump 923
# go go data dump 924
# go go data dump 925
# go go data dump 926
# go go data dump 927
# go go data dump 928
# go go data dump 929
# go go data dump 930
# go go data dump 931
# go go data dump 932
# go go data dump 933
# go go data dump 934
# go go data dump 935
# go go data dump 936
# go go data dump 937
# go go data dump 938
# go go data dump 939
# go go data dump 940
# go go data dump 941
# go go data dump 942
# go go data dump 943
# go go data dump 944
# go go data dump 945
# go go data dump 946
# go go data dump 947
# go go data dump 948
# go go data dump 949
# go go data dump 950
# go go data dump 951
# go go data dump 952
# go go data dump 953
# go go data dump 954
# go go data dump 955
# go go data dump 956
# go go data dump 957
# go go data dump 958
# go go data dump 959
# go go data dump 960
# go go data dump 961
# go go data dump 962
# go go data dump 963
# go go data dump 964
# go go data dump 965
# go go data dump 966
# go go data dump 967
# go go data dump 968
# go go data dump 969
# go go data dump 970
# go go data dump 971
# go go data dump 972
# go go data dump 973
# go go data dump 974
# go go data dump 975
# go go data dump 976
# go go data dump 977
# go go data dump 978
# go go data dump 979
# go go data dump 980
# go go data dump 981
# go go data dump 982
# go go data dump 983
# go go data dump 984
# go go data dump 985
# go go data dump 986
# go go data dump 987
# go go data dump 988
# go go data dump 989
# go go data dump 990
# go go data dump 991
# go go data dump 992
# go go data dump 993
# go go data dump 994
# go go data dump 995
# go go data dump 996
# go go data dump 997
# go go data dump 998
# go go data dump 999
# go go data dump 1000
# go go data dump 1001
# go go data dump 1002
# go go data dump 1003
# go go data dump 1004
# go go data dump 1005
# go go data dump 1006
# go go data dump 1007
# go go data dump 1008
# go go data dump 1009
# go go data dump 1010
# go go data dump 1011
# go go data dump 1012
# go go data dump 1013
# go go data dump 1014
# go go data dump 1015
# go go data dump 1016
# go go data dump 1017
# go go data dump 1018
# go go data dump 1019
# go go data dump 1020
# go go data dump 1021
# go go data dump 1022
# go go data dump 1023
# go go data dump 1024
# go go data dump 1025
# go go data dump 1026
# go go data dump 1027
# go go data dump 1028
# go go data dump 1029
# go go data dump 1030
# go go data dump 1031
# go go data dump 1032
# go go data dump 1033
# go go data dump 1034
# go go data dump 1035
# go go data dump 1036
# go go data dump 1037
# go go data dump 1038
# go go data dump 1039
# go go data dump 1040
# go go data dump 1041
# go go data dump 1042
# go go data dump 1043
# go go data dump 1044
# go go data dump 1045
# go go data dump 1046
# go go data dump 1047
# go go data dump 1048
# go go data dump 1049
# go go data dump 1050
# go go data dump 1051
# go go data dump 1052
# go go data dump 1053
# go go data dump 1054
# go go data dump 1055
# go go data dump 1056
# go go data dump 1057
# go go data dump 1058
# go go data dump 1059
# go go data dump 1060
# go go data dump 1061
# go go data dump 1062
# go go data dump 1063
# go go data dump 1064
# go go data dump 1065
# go go data dump 1066
# go go data dump 1067
# go go data dump 1068
# go go data dump 1069
# go go data dump 1070
# go go data dump 1071
# go go data dump 1072
# go go data dump 1073
# go go data dump 1074
# go go data dump 1075
# go go data dump 1076
# go go data dump 1077
# go go data dump 1078
# go go data dump 1079
# go go data dump 1080
# go go data dump 1081
# go go data dump 1082
# go go data dump 1083
# go go data dump 1084
# go go data dump 1085
# go go data dump 1086
# go go data dump 1087
# go go data dump 1088
# go go data dump 1089
# go go data dump 1090
# go go data dump 1091
# go go data dump 1092
# go go data dump 1093
# go go data dump 1094
# go go data dump 1095
# go go data dump 1096
# go go data dump 1097
# go go data dump 1098
# go go data dump 1099
# go go data dump 1100
# go go data dump 1101
# go go data dump 1102
# go go data dump 1103
# go go data dump 1104
# go go data dump 1105
# go go data dump 1106
# go go data dump 1107
# go go data dump 1108
# go go data dump 1109
# go go data dump 1110
# go go data dump 1111
# go go data dump 1112
# go go data dump 1113
# go go data dump 1114
# go go data dump 1115
# go go data dump 1116
# go go data dump 1117
# go go data dump 1118
# go go data dump 1119
# go go data dump 1120
# go go data dump 1121
# go go data dump 1122
# go go data dump 1123
# go go data dump 1124
# go go data dump 1125
# go go data dump 1126
# go go data dump 1127
# go go data dump 1128
# go go data dump 1129
# go go data dump 1130
# go go data dump 1131
# go go data dump 1132
# go go data dump 1133
# go go data dump 1134
# go go data dump 1135
# go go data dump 1136
# go go data dump 1137
# go go data dump 1138
# go go data dump 1139
# go go data dump 1140
# go go data dump 1141
# go go data dump 1142
# go go data dump 1143
# go go data dump 1144
# go go data dump 1145
# go go data dump 1146
# go go data dump 1147
# go go data dump 1148
# go go data dump 1149
# go go data dump 1150
# go go data dump 1151
# go go data dump 1152
# go go data dump 1153
# go go data dump 1154
# go go data dump 1155
# go go data dump 1156
# go go data dump 1157
# go go data dump 1158
# go go data dump 1159
# go go data dump 1160
# go go data dump 1161
# go go data dump 1162
# go go data dump 1163
# go go data dump 1164
# go go data dump 1165
# go go data dump 1166
# go go data dump 1167
# go go data dump 1168
# go go data dump 1169
# go go data dump 1170
# go go data dump 1171
# go go data dump 1172
# go go data dump 1173
# go go data dump 1174
# go go data dump 1175
# go go data dump 1176
# go go data dump 1177
# go go data dump 1178
# go go data dump 1179
# go go data dump 1180
# go go data dump 1181
# go go data dump 1182
# go go data dump 1183
# go go data dump 1184
# go go data dump 1185
# go go data dump 1186
# go go data dump 1187
# go go data dump 1188
# go go data dump 1189
# go go data dump 1190
# go go data dump 1191
# go go data dump 1192
# go go data dump 1193
# go go data dump 1194
# go go data dump 1195
# go go data dump 1196
# go go data dump 1197
# go go data dump 1198
# go go data dump 1199
# go go data dump 1200
# go go data dump 1201
# go go data dump 1202
# go go data dump 1203
# go go data dump 1204
# go go data dump 1205
# go go data dump 1206
# go go data dump 1207
# go go data dump 1208
# go go data dump 1209
# go go data dump 1210
# go go data dump 1211
# go go data dump 1212
# go go data dump 1213
# go go data dump 1214
# go go data dump 1215
# go go data dump 1216
# go go data dump 1217
# go go data dump 1218
# go go data dump 1219
# go go data dump 1220
# go go data dump 1221
# go go data dump 1222
# go go data dump 1223
# go go data dump 1224
# go go data dump 1225
# go go data dump 1226
# go go data dump 1227
# go go data dump 1228
# go go data dump 1229
# go go data dump 1230
# go go data dump 1231
# go go data dump 1232
# go go data dump 1233
# go go data dump 1234
# go go data dump 1235
# go go data dump 1236
# go go data dump 1237
# go go data dump 1238
# go go data dump 1239
# go go data dump 1240
# go go data dump 1241
# go go data dump 1242
# go go data dump 1243
# go go data dump 1244
# go go data dump 1245
# go go data dump 1246
# go go data dump 1247
# go go data dump 1248
# go go data dump 1249
# go go data dump 1250
# go go data dump 1251
# go go data dump 1252
# go go data dump 1253
# go go data dump 1254
# go go data dump 1255
# go go data dump 1256
# go go data dump 1257
# go go data dump 1258
# go go data dump 1259
# go go data dump 1260
# go go data dump 1261
# go go data dump 1262
# go go data dump 1263
# go go data dump 1264
# go go data dump 1265
# go go data dump 1266
# go go data dump 1267
# go go data dump 1268
# go go data dump 1269
# go go data dump 1270
# go go data dump 1271
# go go data dump 1272
# go go data dump 1273
# go go data dump 1274
# go go data dump 1275
# go go data dump 1276
# go go data dump 1277
# go go data dump 1278
# go go data dump 1279
# go go data dump 1280
# go go data dump 1281
# go go data dump 1282
# go go data dump 1283
# go go data dump 1284
# go go data dump 1285
# go go data dump 1286
# go go data dump 1287
# go go data dump 1288
# go go data dump 1289
# go go data dump 1290
# go go data dump 1291
# go go data dump 1292
# go go data dump 1293
# go go data dump 1294
# go go data dump 1295
# go go data dump 1296
# go go data dump 1297
# go go data dump 1298
# go go data dump 1299
# go go data dump 1300
# go go data dump 1301
# go go data dump 1302
# go go data dump 1303
# go go data dump 1304
# go go data dump 1305
# go go data dump 1306
# go go data dump 1307
# go go data dump 1308
# go go data dump 1309
# go go data dump 1310
# go go data dump 1311
# go go data dump 1312
# go go data dump 1313
# go go data dump 1314
# go go data dump 1315
# go go data dump 1316
# go go data dump 1317
# go go data dump 1318
# go go data dump 1319
# go go data dump 1320
# go go data dump 1321
# go go data dump 1322
# go go data dump 1323
# go go data dump 1324
# go go data dump 1325
# go go data dump 1326
# go go data dump 1327
# go go data dump 1328
# go go data dump 1329
# go go data dump 1330
# go go data dump 1331
# go go data dump 1332
# go go data dump 1333
# go go data dump 1334
# go go data dump 1335
# go go data dump 1336
# go go data dump 1337
# go go data dump 1338
# go go data dump 1339
# go go data dump 1340
# go go data dump 1341
# go go data dump 1342
# go go data dump 1343
# go go data dump 1344
# go go data dump 1345
# go go data dump 1346
# go go data dump 1347
# go go data dump 1348
# go go data dump 1349
# go go data dump 1350
# go go data dump 1351
# go go data dump 1352
# go go data dump 1353
# go go data dump 1354
# go go data dump 1355
# go go data dump 1356
# go go data dump 1357
# go go data dump 1358
# go go data dump 1359
# go go data dump 1360
# go go data dump 1361
# go go data dump 1362
# go go data dump 1363
# go go data dump 1364
# go go data dump 1365
# go go data dump 1366
# go go data dump 1367
# go go data dump 1368
# go go data dump 1369
# go go data dump 1370
# go go data dump 1371
# go go data dump 1372
# go go data dump 1373
# go go data dump 1374
# go go data dump 1375
# go go data dump 1376
# go go data dump 1377
# go go data dump 1378
# go go data dump 1379
# go go data dump 1380
# go go data dump 1381
# go go data dump 1382
# go go data dump 1383
# go go data dump 1384
# go go data dump 1385
# go go data dump 1386
# go go data dump 1387
# go go data dump 1388
# go go data dump 1389
# go go data dump 1390
# go go data dump 1391
# go go data dump 1392
# go go data dump 1393
# go go data dump 1394
# go go data dump 1395
# go go data dump 1396
# go go data dump 1397
# go go data dump 1398
# go go data dump 1399
# go go data dump 1400
# go go data dump 1401
# go go data dump 1402
# go go data dump 1403
# go go data dump 1404
# go go data dump 1405
# go go data dump 1406
# go go data dump 1407
# go go data dump 1408
# go go data dump 1409
# go go data dump 1410
# go go data dump 1411
# go go data dump 1412
# go go data dump 1413
# go go data dump 1414
# go go data dump 1415
# go go data dump 1416
# go go data dump 1417
# go go data dump 1418
# go go data dump 1419
# go go data dump 1420
# go go data dump 1421
# go go data dump 1422
# go go data dump 1423
# go go data dump 1424
# go go data dump 1425
# go go data dump 1426
# go go data dump 1427
# go go data dump 1428
# go go data dump 1429
# go go data dump 1430
# go go data dump 1431
# go go data dump 1432
# go go data dump 1433
# go go data dump 1434
# go go data dump 1435
# go go data dump 1436
# go go data dump 1437
# go go data dump 1438
# go go data dump 1439
# go go data dump 1440
# go go data dump 1441
# go go data dump 1442
# go go data dump 1443
# go go data dump 1444
# go go data dump 1445
# go go data dump 1446
# go go data dump 1447
# go go data dump 1448
# go go data dump 1449
# go go data dump 1450
# go go data dump 1451
# go go data dump 1452
# go go data dump 1453
# go go data dump 1454
# go go data dump 1455
# go go data dump 1456
# go go data dump 1457
# go go data dump 1458
# go go data dump 1459
# go go data dump 1460
# go go data dump 1461
# go go data dump 1462
# go go data dump 1463
# go go data dump 1464
# go go data dump 1465
# go go data dump 1466
# go go data dump 1467
# go go data dump 1468
# go go data dump 1469
# go go data dump 1470
# go go data dump 1471
# go go data dump 1472
# go go data dump 1473
# go go data dump 1474
# go go data dump 1475
# go go data dump 1476
# go go data dump 1477
# go go data dump 1478
# go go data dump 1479
# go go data dump 1480
# go go data dump 1481
# go go data dump 1482
# go go data dump 1483
# go go data dump 1484
# go go data dump 1485
# go go data dump 1486
# go go data dump 1487
# go go data dump 1488
# go go data dump 1489
# go go data dump 1490
# go go data dump 1491
# go go data dump 1492
# go go data dump 1493
# go go data dump 1494
# go go data dump 1495
# go go data dump 1496
# go go data dump 1497
# go go data dump 1498
# go go data dump 1499
# go go data dump 1500
# go go data dump 1501
# go go data dump 1502
# go go data dump 1503
# go go data dump 1504
# go go data dump 1505
# go go data dump 1506
# go go data dump 1507
# go go data dump 1508
# go go data dump 1509
# go go data dump 1510
# go go data dump 1511
# go go data dump 1512
# go go data dump 1513
# go go data dump 1514
# go go data dump 1515
# go go data dump 1516
# go go data dump 1517
# go go data dump 1518
# go go data dump 1519
# go go data dump 1520
# go go data dump 1521
# go go data dump 1522
# go go data dump 1523
# go go data dump 1524
# go go data dump 1525
# go go data dump 1526
# go go data dump 1527
# go go data dump 1528
# go go data dump 1529
# go go data dump 1530
# go go data dump 1531
# go go data dump 1532
# go go data dump 1533
# go go data dump 1534
# go go data dump 1535
# go go data dump 1536
# go go data dump 1537
# go go data dump 1538
# go go data dump 1539
# go go data dump 1540
# go go data dump 1541
# go go data dump 1542
# go go data dump 1543
# go go data dump 1544
# go go data dump 1545
# go go data dump 1546
# go go data dump 1547
# go go data dump 1548
# go go data dump 1549
# go go data dump 1550
# go go data dump 1551
# go go data dump 1552
# go go data dump 1553
# go go data dump 1554
# go go data dump 1555
# go go data dump 1556
# go go data dump 1557
# go go data dump 1558
# go go data dump 1559
# go go data dump 1560
# go go data dump 1561
# go go data dump 1562
# go go data dump 1563
# go go data dump 1564
# go go data dump 1565
# go go data dump 1566
# go go data dump 1567
# go go data dump 1568
# go go data dump 1569
# go go data dump 1570
# go go data dump 1571
# go go data dump 1572
# go go data dump 1573
# go go data dump 1574
# go go data dump 1575
# go go data dump 1576
# go go data dump 1577
# go go data dump 1578
# go go data dump 1579
# go go data dump 1580
# go go data dump 1581
# go go data dump 1582
# go go data dump 1583
# go go data dump 1584
# go go data dump 1585
# go go data dump 1586
# go go data dump 1587
# go go data dump 1588
# go go data dump 1589
# go go data dump 1590
# go go data dump 1591
# go go data dump 1592
# go go data dump 1593
# go go data dump 1594
# go go data dump 1595
# go go data dump 1596
# go go data dump 1597
# go go data dump 1598
# go go data dump 1599
# go go data dump 1600
# go go data dump 1601
# go go data dump 1602
# go go data dump 1603
# go go data dump 1604
# go go data dump 1605
# go go data dump 1606
# go go data dump 1607
# go go data dump 1608
# go go data dump 1609
# go go data dump 1610
# go go data dump 1611
# go go data dump 1612
# go go data dump 1613
# go go data dump 1614
# go go data dump 1615
# go go data dump 1616
# go go data dump 1617
# go go data dump 1618
# go go data dump 1619
# go go data dump 1620
# go go data dump 1621
# go go data dump 1622
# go go data dump 1623
# go go data dump 1624
# go go data dump 1625
# go go data dump 1626
# go go data dump 1627
# go go data dump 1628
# go go data dump 1629
# go go data dump 1630
# go go data dump 1631
# go go data dump 1632
# go go data dump 1633
# go go data dump 1634
# go go data dump 1635
# go go data dump 1636
# go go data dump 1637
# go go data dump 1638
# go go data dump 1639
# go go data dump 1640
# go go data dump 1641
# go go data dump 1642
# go go data dump 1643
# go go data dump 1644
# go go data dump 1645
# go go data dump 1646
# go go data dump 1647
# go go data dump 1648
# go go data dump 1649
# go go data dump 1650
# go go data dump 1651
# go go data dump 1652
# go go data dump 1653
# go go data dump 1654
# go go data dump 1655
# go go data dump 1656
# go go data dump 1657
# go go data dump 1658
# go go data dump 1659
# go go data dump 1660
# go go data dump 1661
# go go data dump 1662
# go go data dump 1663
# go go data dump 1664
# go go data dump 1665
# go go data dump 1666
# go go data dump 1667
# go go data dump 1668
# go go data dump 1669
# go go data dump 1670
# go go data dump 1671
# go go data dump 1672
# go go data dump 1673
# go go data dump 1674
# go go data dump 1675
# go go data dump 1676
# go go data dump 1677
# go go data dump 1678
# go go data dump 1679
# go go data dump 1680
# go go data dump 1681
# go go data dump 1682
# go go data dump 1683
# go go data dump 1684
# go go data dump 1685
# go go data dump 1686
# go go data dump 1687
# go go data dump 1688
# go go data dump 1689
# go go data dump 1690
# go go data dump 1691
# go go data dump 1692
# go go data dump 1693
# go go data dump 1694
# go go data dump 1695
# go go data dump 1696
# go go data dump 1697
# go go data dump 1698
# go go data dump 1699
# go go data dump 1700
# go go data dump 1701
# go go data dump 1702
# go go data dump 1703
# go go data dump 1704
# go go data dump 1705
# go go data dump 1706
# go go data dump 1707
# go go data dump 1708
# go go data dump 1709
# go go data dump 1710
# go go data dump 1711
# go go data dump 1712
# go go data dump 1713
# go go data dump 1714
# go go data dump 1715
# go go data dump 1716
# go go data dump 1717
# go go data dump 1718
# go go data dump 1719
# go go data dump 1720
# go go data dump 1721
# go go data dump 1722
# go go data dump 1723
# go go data dump 1724
# go go data dump 1725
# go go data dump 1726
# go go data dump 1727
# go go data dump 1728
# go go data dump 1729
# go go data dump 1730
# go go data dump 1731
# go go data dump 1732
# go go data dump 1733
# go go data dump 1734
# go go data dump 1735
# go go data dump 1736
# go go data dump 1737
# go go data dump 1738
# go go data dump 1739
# go go data dump 1740
# go go data dump 1741
# go go data dump 1742
# go go data dump 1743
# go go data dump 1744
# go go data dump 1745
# go go data dump 1746
# go go data dump 1747
# go go data dump 1748
# go go data dump 1749
# go go data dump 1750
# go go data dump 1751
# go go data dump 1752
# go go data dump 1753
# go go data dump 1754
# go go data dump 1755
# go go data dump 1756
# go go data dump 1757
# go go data dump 1758
# go go data dump 1759
# go go data dump 1760
# go go data dump 1761
# go go data dump 1762
# go go data dump 1763
# go go data dump 1764
# go go data dump 1765
# go go data dump 1766
# go go data dump 1767
# go go data dump 1768
# go go data dump 1769
# go go data dump 1770
# go go data dump 1771
# go go data dump 1772
# go go data dump 1773
# go go data dump 1774
# go go data dump 1775
# go go data dump 1776
# go go data dump 1777
# go go data dump 1778
# go go data dump 1779
# go go data dump 1780
# go go data dump 1781
# go go data dump 1782
# go go data dump 1783
# go go data dump 1784
# go go data dump 1785
# go go data dump 1786
# go go data dump 1787
# go go data dump 1788
# go go data dump 1789
# go go data dump 1790
# go go data dump 1791
# go go data dump 1792
# go go data dump 1793
# go go data dump 1794
# go go data dump 1795
# go go data dump 1796
# go go data dump 1797
# go go data dump 1798
# go go data dump 1799
# go go data dump 1800
# go go data dump 1801
# go go data dump 1802
# go go data dump 1803
# go go data dump 1804
# go go data dump 1805
# go go data dump 1806
# go go data dump 1807
# go go data dump 1808
# go go data dump 1809
# go go data dump 1810
# go go data dump 1811
# go go data dump 1812
# go go data dump 1813
# go go data dump 1814
# go go data dump 1815
# go go data dump 1816
# go go data dump 1817
# go go data dump 1818
# go go data dump 1819
# go go data dump 1820
# go go data dump 1821
# go go data dump 1822
# go go data dump 1823
# go go data dump 1824
# go go data dump 1825
# go go data dump 1826
# go go data dump 1827
# go go data dump 1828
# go go data dump 1829
# go go data dump 1830
# go go data dump 1831
# go go data dump 1832
# go go data dump 1833
# go go data dump 1834
# go go data dump 1835
# go go data dump 1836
# go go data dump 1837
# go go data dump 1838
# go go data dump 1839
# go go data dump 1840
# go go data dump 1841
# go go data dump 1842
# go go data dump 1843
# go go data dump 1844
# go go data dump 1845
# go go data dump 1846
# go go data dump 1847
# go go data dump 1848
# go go data dump 1849
# go go data dump 1850
# go go data dump 1851
# go go data dump 1852
# go go data dump 1853
# go go data dump 1854
# go go data dump 1855
# go go data dump 1856
# go go data dump 1857
# go go data dump 1858
# go go data dump 1859
# go go data dump 1860
# go go data dump 1861
# go go data dump 1862
# go go data dump 1863
# go go data dump 1864
# go go data dump 1865
# go go data dump 1866
# go go data dump 1867
# go go data dump 1868
# go go data dump 1869
# go go data dump 1870
# go go data dump 1871
# go go data dump 1872
# go go data dump 1873
# go go data dump 1874
# go go data dump 1875
# go go data dump 1876
# go go data dump 1877
# go go data dump 1878
# go go data dump 1879
# go go data dump 1880
# go go data dump 1881
# go go data dump 1882
# go go data dump 1883
# go go data dump 1884
# go go data dump 1885
# go go data dump 1886
# go go data dump 1887
# go go data dump 1888
# go go data dump 1889
# go go data dump 1890
# go go data dump 1891
# go go data dump 1892
# go go data dump 1893
# go go data dump 1894
# go go data dump 1895
# go go data dump 1896
# go go data dump 1897
# go go data dump 1898
# go go data dump 1899
# go go data dump 1900
# go go data dump 1901
# go go data dump 1902
# go go data dump 1903
# go go data dump 1904
# go go data dump 1905
# go go data dump 1906
# go go data dump 1907
# go go data dump 1908
# go go data dump 1909
# go go data dump 1910
# go go data dump 1911
# go go data dump 1912
# go go data dump 1913
# go go data dump 1914
# go go data dump 1915
# go go data dump 1916
# go go data dump 1917
# go go data dump 1918
# go go data dump 1919
# go go data dump 1920
# go go data dump 1921
# go go data dump 1922
# go go data dump 1923
# go go data dump 1924
# go go data dump 1925
# go go data dump 1926
# go go data dump 1927
# go go data dump 1928
# go go data dump 1929
# go go data dump 1930
# go go data dump 1931
# go go data dump 1932
# go go data dump 1933
# go go data dump 1934
# go go data dump 1935
# go go data dump 1936
# go go data dump 1937
# go go data dump 1938
# go go data dump 1939
# go go data dump 1940
# go go data dump 1941
# go go data dump 1942
# go go data dump 1943
# go go data dump 1944
# go go data dump 1945
# go go data dump 1946
# go go data dump 1947
# go go data dump 1948
# go go data dump 1949
# go go data dump 1950
# go go data dump 1951
# go go data dump 1952
# go go data dump 1953
# go go data dump 1954
# go go data dump 1955
# go go data dump 1956
# go go data dump 1957
# go go data dump 1958
# go go data dump 1959
# go go data dump 1960
# go go data dump 1961
# go go data dump 1962
# go go data dump 1963
# go go data dump 1964
# go go data dump 1965
# go go data dump 1966
# go go data dump 1967
# go go data dump 1968
# go go data dump 1969
# go go data dump 1970
# go go data dump 1971
# go go data dump 1972
# go go data dump 1973
# go go data dump 1974
# go go data dump 1975
# go go data dump 1976
# go go data dump 1977
# go go data dump 1978
# go go data dump 1979
# go go data dump 1980
# go go data dump 1981
# go go data dump 1982
# go go data dump 1983
# go go data dump 1984
# go go data dump 1985
# go go data dump 1986
# go go data dump 1987
# go go data dump 1988
# go go data dump 1989
# go go data dump 1990
# go go data dump 1991
# go go data dump 1992
# go go data dump 1993
# go go data dump 1994
# go go data dump 1995
# go go data dump 1996
# go go data dump 1997
# go go data dump 1998
# go go data dump 1999
# go go data dump 2000
# go go data dump 2001
# go go data dump 2002
# go go data dump 2003
# go go data dump 2004
# go go data dump 2005
# go go data dump 2006
# go go data dump 2007
# go go data dump 2008
# go go data dump 2009
# go go data dump 2010
# go go data dump 2011
# go go data dump 2012
# go go data dump 2013
# go go data dump 2014
# go go data dump 2015
# go go data dump 2016
# go go data dump 2017
# go go data dump 2018
# go go data dump 2019
# go go data dump 2020
# go go data dump 2021
# go go data dump 2022
# go go data dump 2023
# go go data dump 2024
# go go data dump 2025
# go go data dump 2026
# go go data dump 2027
# go go data dump 2028
# go go data dump 2029
# go go data dump 2030
# go go data dump 2031
# go go data dump 2032
# go go data dump 2033
# go go data dump 2034
# go go data dump 2035
# go go data dump 2036
# go go data dump 2037
# go go data dump 2038
# go go data dump 2039
# go go data dump 2040
# go go data dump 2041
# go go data dump 2042
# go go data dump 2043
# go go data dump 2044
# go go data dump 2045
# go go data dump 2046
# go go data dump 2047
# go go data dump 2048
# go go data dump 2049
# go go data dump 2050
# go go data dump 2051
# go go data dump 2052
# go go data dump 2053
# go go data dump 2054
# go go data dump 2055
# go go data dump 2056
# go go data dump 2057
# go go data dump 2058
# go go data dump 2059
# go go data dump 2060
# go go data dump 2061
# go go data dump 2062
# go go data dump 2063
# go go data dump 2064
# go go data dump 2065
# go go data dump 2066
# go go data dump 2067
# go go data dump 2068
# go go data dump 2069
# go go data dump 2070
# go go data dump 2071
# go go data dump 2072
# go go data dump 2073
# go go data dump 2074
# go go data dump 2075
# go go data dump 2076
# go go data dump 2077
# go go data dump 2078
# go go data dump 2079
# go go data dump 2080
# go go data dump 2081
# go go data dump 2082
# go go data dump 2083
# go go data dump 2084
# go go data dump 2085
# go go data dump 2086
# go go data dump 2087
# go go data dump 2088
# go go data dump 2089
# go go data dump 2090
# go go data dump 2091
# go go data dump 2092
# go go data dump 2093
# go go data dump 2094
# go go data dump 2095
# go go data dump 2096
# go go data dump 2097
# go go data dump 2098
# go go data dump 2099
# go go data dump 2100
# go go data dump 2101
# go go data dump 2102
# go go data dump 2103
# go go data dump 2104
# go go data dump 2105
# go go data dump 2106
# go go data dump 2107
# go go data dump 2108
# go go data dump 2109
# go go data dump 2110
# go go data dump 2111
# go go data dump 2112
# go go data dump 2113
# go go data dump 2114
# go go data dump 2115
# go go data dump 2116
# go go data dump 2117
# go go data dump 2118
# go go data dump 2119
# go go data dump 2120
# go go data dump 2121
# go go data dump 2122
# go go data dump 2123
# go go data dump 2124
# go go data dump 2125
# go go data dump 2126
# go go data dump 2127
# go go data dump 2128
# go go data dump 2129
# go go data dump 2130
# go go data dump 2131
# go go data dump 2132
# go go data dump 2133
# go go data dump 2134
# go go data dump 2135
# go go data dump 2136
# go go data dump 2137
# go go data dump 2138
# go go data dump 2139
# go go data dump 2140
# go go data dump 2141
# go go data dump 2142
# go go data dump 2143
# go go data dump 2144
# go go data dump 2145
# go go data dump 2146
# go go data dump 2147
# go go data dump 2148
# go go data dump 2149
# go go data dump 2150
# go go data dump 2151
# go go data dump 2152
# go go data dump 2153
# go go data dump 2154
# go go data dump 2155
# go go data dump 2156
# go go data dump 2157
# go go data dump 2158
# go go data dump 2159
# go go data dump 2160
# go go data dump 2161
# go go data dump 2162
# go go data dump 2163
# go go data dump 2164
# go go data dump 2165
# go go data dump 2166
# go go data dump 2167
# go go data dump 2168
# go go data dump 2169
# go go data dump 2170
# go go data dump 2171
# go go data dump 2172
# go go data dump 2173
# go go data dump 2174
# go go data dump 2175
# go go data dump 2176
# go go data dump 2177
# go go data dump 2178
# go go data dump 2179
# go go data dump 2180
# go go data dump 2181
# go go data dump 2182
# go go data dump 2183
# go go data dump 2184
# go go data dump 2185
# go go data dump 2186
# go go data dump 2187
# go go data dump 2188
# go go data dump 2189
# go go data dump 2190
# go go data dump 2191
# go go data dump 2192
# go go data dump 2193
# go go data dump 2194
# go go data dump 2195
# go go data dump 2196
# go go data dump 2197
# go go data dump 2198
# go go data dump 2199
# go go data dump 2200
# go go data dump 2201
# go go data dump 2202
# go go data dump 2203
# go go data dump 2204
# go go data dump 2205
# go go data dump 2206
# go go data dump 2207
# go go data dump 2208
# go go data dump 2209
# go go data dump 2210
# go go data dump 2211
# go go data dump 2212
# go go data dump 2213
# go go data dump 2214
# go go data dump 2215
# go go data dump 2216
# go go data dump 2217
# go go data dump 2218
# go go data dump 2219
# go go data dump 2220
# go go data dump 2221
# go go data dump 2222
# go go data dump 2223
# go go data dump 2224
# go go data dump 2225
# go go data dump 2226
# go go data dump 2227
# go go data dump 2228
# go go data dump 2229
# go go data dump 2230
# go go data dump 2231
# go go data dump 2232
# go go data dump 2233
# go go data dump 2234
# go go data dump 2235
# go go data dump 2236
# go go data dump 2237
# go go data dump 2238
# go go data dump 2239
# go go data dump 2240
# go go data dump 2241
# go go data dump 2242
# go go data dump 2243
# go go data dump 2244
# go go data dump 2245
# go go data dump 2246
# go go data dump 2247
# go go data dump 2248
# go go data dump 2249
# go go data dump 2250
# go go data dump 2251
# go go data dump 2252
# go go data dump 2253
# go go data dump 2254
# go go data dump 2255
# go go data dump 2256
# go go data dump 2257
# go go data dump 2258
# go go data dump 2259
# go go data dump 2260
# go go data dump 2261
# go go data dump 2262
# go go data dump 2263
# go go data dump 2264
# go go data dump 2265
# go go data dump 2266
# go go data dump 2267
# go go data dump 2268
# go go data dump 2269
# go go data dump 2270
# go go data dump 2271
# go go data dump 2272
# go go data dump 2273
# go go data dump 2274
# go go data dump 2275
# go go data dump 2276
# go go data dump 2277
# go go data dump 2278
# go go data dump 2279
# go go data dump 2280
# go go data dump 2281
# go go data dump 2282
# go go data dump 2283
# go go data dump 2284
# go go data dump 2285
# go go data dump 2286
# go go data dump 2287
# go go data dump 2288
# go go data dump 2289
# go go data dump 2290
# go go data dump 2291
# go go data dump 2292
# go go data dump 2293
# go go data dump 2294
# go go data dump 2295
# go go data dump 2296
# go go data dump 2297
# go go data dump 2298
# go go data dump 2299
# go go data dump 2300
# go go data dump 2301
# go go data dump 2302
# go go data dump 2303
# go go data dump 2304
# go go data dump 2305
# go go data dump 2306
# go go data dump 2307
# go go data dump 2308
# go go data dump 2309
# go go data dump 2310
# go go data dump 2311
# go go data dump 2312
# go go data dump 2313
# go go data dump 2314
# go go data dump 2315
# go go data dump 2316
# go go data dump 2317
# go go data dump 2318
# go go data dump 2319
# go go data dump 2320
# go go data dump 2321
# go go data dump 2322
# go go data dump 2323
# go go data dump 2324
# go go data dump 2325
# go go data dump 2326
# go go data dump 2327
# go go data dump 2328
# go go data dump 2329
# go go data dump 2330
# go go data dump 2331
# go go data dump 2332
# go go data dump 2333
# go go data dump 2334
# go go data dump 2335
# go go data dump 2336
# go go data dump 2337
# ...
# go go data dump 3162
# go go data dump 3163
# go go data dump 3164
# go go data dump 3165
# go go data dump 3166
# go go data dump 3167
# go go data dump 3168
# go go data dump 3169
# go go data dump 3170
# go go data dump 3171
# go go data dump 3172
# go go data dump 3173
# go go data dump 3174
# go go data dump 3175
# go go data dump 3176
# go go data dump 3177
# go go data dump 3178
# go go data dump 3179
# go go data dump 3180
# go go data dump 3181
# go go data dump 3182
# go go data dump 3183
# go go data dump 3184
# go go data dump 3185
# go go data dump 3186
# go go data dump 3187
# go go data dump 3188
# go go data dump 3189
# go go data dump 3190
# go go data dump 3191
# go go data dump 3192
# go go data dump 3193
# go go data dump 3194
# go go data dump 3195
# go go data dump 3196
# go go data dump 3197
# go go data dump 3198
# go go data dump 3199
# go go data dump 3200
# go go data dump 3201
# go go data dump 3202
# go go data dump 3203
# go go data dump 3204
# go go data dump 3205
# go go data dump 3206
# go go data dump 3207
# go go data dump 3208
# go go data dump 3209
# go go data dump 3210
# go go data dump 3211
# go go data dump 3212
# go go data dump 3213
# go go data dump 3214
# go go data dump 3215
# go go data dump 3216
# go go data dump 3217
# go go data dump 3218
# go go data dump 3219
# go go data dump 3220
# go go data dump 3221
# go go data dump 3222
# go go data dump 3223
# go go data dump 3224
# go go data dump 3225
# go go data dump 3226
# go go data dump 3227
# go go data dump 3228
# go go data dump 3229
# go go data dump 3230
# go go data dump 3231
# go go data dump 3232
# go go data dump 3233
# go go data dump 3234
# go go data dump 3235
# go go data dump 3236
# go go data dump 3237
# go go data dump 3238
# go go data dump 3239
# go go data dump 3240
# go go data dump 3241
# go go data dump 3242
# go go data dump 3243
# go go data dump 3244
# go go data dump 3245
# go go data dump 3246
# go go data dump 3247
# go go data dump 3248
# go go data dump 3249
# go go data dump 3250
# go go data dump 3251
# go go data dump 3252
# go go data dump 3253
# go go data dump 3254
# go go data dump 3255
# go go data dump 3256
# go go data dump 3257
# go go data dump 3258
# go go data dump 3259
# go go data dump 3260
# go go data dump 3261
# go go data dump 3262
# go go data dump 3263
# go go data dump 3264
# go go data dump 3265
# go go data dump 3266
# go go data dump 3267
# go go data dump 3268
# go go data dump 3269
# go go data dump 3270
# go go data dump 3271
# go go data dump 3272
# go go data dump 3273
# go go data dump 3274
# go go data dump 3275
# go go data dump 3276
# go go data dump 3277
# go go data dump 3278
# go go data dump 3279
# go go data dump 3280
# go go data dump 3281
# go go data dump 3282
# go go data dump 3283
# go go data dump 3284
# go go data dump 3285
# go go data dump 3286
# go go data dump 3287
# go go data dump 3288
# go go data dump 3289
# go go data dump 3290
# go go data dump 3291
# go go data dump 3292
# go go data dump 3293
# go go data dump 3294
# go go data dump 3295
# go go data dump 3296
# go go data dump 3297
# go go data dump 3298
# go go data dump 3299
# go go data dump 3300
# go go data dump 3301
# go go data dump 3302
# go go data dump 3303
# go go data dump 3304
# go go data dump 3305
# go go data dump 3306
# go go data dump 3307
# go go data dump 3308
# go go data dump 3309
# go go data dump 3310
# go go data dump 3311
# go go data dump 3312
# go go data dump 3313
# go go data dump 3314
# go go data dump 3315
# go go data dump 3316
# go go data dump 3317
# go go data dump 3318
# go go data dump 3319
# go go data dump 3320
# go go data dump 3321
# go go data dump 3322
# go go data dump 3323
# go go data dump 3324
# go go data dump 3325
# go go data dump 3326
# go go data dump 3327
# go go data dump 3328
# go go data dump 3329
# go go data dump 3330
# go go data dump 3331
# go go data dump 3332
# go go data dump 3333
# go go data dump 3334
# go go data dump 3335
# go go data dump 3336
# go go data dump 3337
# go go data dump 3338
# go go data dump 3339
# go go data dump 3340
# go go data dump 3341
# go go data dump 3342
# go go data dump 3343
# go go data dump 3344
# go go data dump 3345
# go go data dump 3346
# go go data dump 3347
# go go data dump 3348
# go go data dump 3349
# go go data dump 3350
# go go data dump 3351
# go go data dump 3352
# go go data dump 3353
# go go data dump 3354
# go go data dump 3355
# go go data dump 3356
# go go data dump 3357
# go go data dump 3358
# go go data dump 3359
# go go data dump 3360
# go go data dump 3361
# go go data dump 3362
# go go data dump 3363
# go go data dump 3364
# go go data dump 3365
# go go data dump 3366
# go go data dump 3367
# go go data dump 3368
# go go data dump 3369
# go go data dump 3370
# go go data dump 3371
# go go data dump 3372
# go go data dump 3373
# go go data dump 3374
# go go data dump 3375
# go go data dump 3376
# go go data dump 3377
# go go data dump 3378
# go go data dump 3379
# go go data dump 3380
# go go data dump 3381
# go go data dump 3382
# go go data dump 3383
# go go data dump 3384
# go go data dump 3385
# go go data dump 3386
# go go data dump 3387
# go go data dump 3388
# go go data dump 3389
# go go data dump 3390
# go go data dump 3391
# go go data dump 3392
# go go data dump 3393
# go go data dump 3394
# go go data dump 3395
# go go data dump 3396
# go go data dump 3397
# go go data dump 3398
# go go data dump 3399
# go go data dump 3400
# go go data dump 3401
# go go data dump 3402
# go go data dump 3403
# go go data dump 3404
# go go data dump 3405
# go go data dump 3406
# go go data dump 3407
# go go data dump 3408
# go go data dump 3409
# go go data dump 3410
# go go data dump 3411
# go go data dump 3412
# go go data dump 3413
# go go data dump 3414
# go go data dump 3415
# go go data dump 3416
# go go data dump 3417
# go go data dump 3418
# go go data dump 3419
# go go data dump 3420
# go go data dump 3421
# go go data dump 3422
# go go data dump 3423
# go go data dump 3424
# go go data dump 3425
# go go data dump 3426
# go go data dump 3427
# go go data dump 3428
# go go data dump 3429
# go go data dump 3430
# go go data dump 3431
# go go data dump 3432
# go go data dump 3433
# go go data dump 3434
# go go data dump 3435
# go go data dump 3436
# go go data dump 3437
# go go data dump 3438
# go go data dump 3439
# go go data dump 3440
# go go data dump 3441
# go go data dump 3442
# go go data dump 3443
# go go data dump 3444
# go go data dump 3445
# go go data dump 3446
# go go data dump 3447
# go go data dump 3448
# go go data dump 3449
# go go data dump 3450
# go go data dump 3451
# go go data dump 3452
# go go data dump 3453
# go go data dump 3454
# go go data dump 3455
# go go data dump 3456
# go go data dump 3457
# go go data dump 3458
# go go data dump 3459
# go go data dump 3460
# go go data dump 3461
# go go data dump 3462
# go go data dump 3463
# go go data dump 3464
# go go data dump 3465
# go go data dump 3466
# go go data dump 3467
# go go data dump 3468
# go go data dump 3469
# go go data dump 3470
# go go data dump 3471
# go go data dump 3472
# go go data dump 3473
# go go data dump 3474
# go go data dump 3475
# go go data dump 3476
# go go data dump 3477
# go go data dump 3478
# go go data dump 3479
# go go data dump 3480
# go go data dump 3481
# go go data dump 3482
# go go data dump 3483
# go go data dump 3484
# go go data dump 3485
# go go data dump 3486
# go go data dump 3487
# go go data dump 3488
# go go data dump 3489
# go go data dump 3490
# go go data dump 3491
# go go data dump 3492
# go go data dump 3493
# go go data dump 3494
# go go data dump 3495
# go go data dump 3496
# go go data dump 3497
# go go data dump 3498
# go go data dump 3499
# go go data dump 3500
# go go data dump 3501
# go go data dump 3502
# go go data dump 3503
# go go data dump 3504
# go go data dump 3505
# go go data dump 3506
# go go data dump 3507
# go go data dump 3508
# go go data dump 3509
# go go data dump 3510
# go go data dump 3511
# go go data dump 3512
# go go data dump 3513
# go go data dump 3514
# go go data dump 3515
# go go data dump 3516
# go go data dump 3517
# go go data dump 3518
# go go data dump 3519
# go go data dump 3520
# go go data dump 3521
# go go data dump 3522
# go go data dump 3523
# go go data dump 3524
# go go data dump 3525
# go go data dump 3526
# go go data dump 3527
# go go data dump 3528
# go go data dump 3529
# go go data dump 3530
# go go data dump 3531
# go go data dump 3532
# go go data dump 3533
# go go data dump 3534
# go go data dump 3535
# go go data dump 3536
# go go data dump 3537
# go go data dump 3538
# go go data dump 3539
# go go data dump 3540
# go go data dump 3541
# go go data dump 3542
# go go data dump 3543
# go go data dump 3544
# go go data dump 3545
# go go data dump 3546
# go go data dump 3547
# go go data dump 3548
# go go data dump 3549
# go go data dump 3550
# go go data dump 3551
# go go data dump 3552
# go go data dump 3553
# go go data dump 3554
# go go data dump 3555
# go go data dump 3556
# go go data dump 3557
# go go data dump 3558
# go go data dump 3559
# go go data dump 3560
# go go data dump 3561
# go go data dump 3562
# go go data dump 3563
# go go data dump 3564
# go go data dump 3565
# go go data dump 3566
# go go data dump 3567
# go go data dump 3568
# go go data dump 3569
# go go data dump 3570
# go go data dump 3571
# go go data dump 3572
# go go data dump 3573
# go go data dump 3574
# go go data dump 3575
# go go data dump 3576
# go go data dump 3577
# go go data dump 3578
# go go data dump 3579
# go go data dump 3580
# go go data dump 3581
# go go data dump 3582
# go go data dump 3583
# go go data dump 3584
# go go data dump 3585
# go go data dump 3586
# go go data dump 3587
# go go data dump 3588
# go go data dump 3589
# go go data dump 3590
# go go data dump 3591
# go go data dump 3592
# go go data dump 3593
# go go data dump 3594
# go go data dump 3595
# go go data dump 3596
# go go data dump 3597
# go go data dump 3598
# go go data dump 3599
# go go data dump 3600
# go go data dump 3601
# go go data dump 3602
# go go data dump 3603
# go go data dump 3604
# go go data dump 3605
# go go data dump 3606
# go go data dump 3607
# go go data dump 3608
# go go data dump 3609
# go go data dump 3610
# go go data dump 3611
# go go data dump 3612
# go go data dump 3613
# go go data dump 3614
# go go data dump 3615
# go go data dump 3616
# go go data dump 3617
# go go data dump 3618
# go go data dump 3619
# go go data dump 3620
# go go data dump 3621
# go go data dump 3622
# go go data dump 3623
# go go data dump 3624
# go go data dump 3625
# go go data dump 3626
# go go data dump 3627
# go go data dump 3628
# go go data dump 3629
# go go data dump 3630
# go go data dump 3631
# go go data dump 3632
# go go data dump 3633
# go go data dump 3634
# go go data dump 3635
# go go data dump 3636
# go go data dump 3637
# go go data dump 3638
# go go data dump 3639
# go go data dump 3640
# go go data dump 3641
# go go data dump 3642
# go go data dump 3643
# go go data dump 3644
# go go data dump 3645
# go go data dump 3646
# go go data dump 3647
# go go data dump 3648
# go go data dump 3649
# go go data dump 3650
# go go data dump 3651
# go go data dump 3652
# go go data dump 3653
# go go data dump 3654
# go go data dump 3655
# go go data dump 3656
# go go data dump 3657
# go go data dump 3658
# go go data dump 3659
# go go data dump 3660
# go go data dump 3661
# go go data dump 3662
# go go data dump 3663
# go go data dump 3664
# go go data dump 3665
# go go data dump 3666
# go go data dump 3667
# go go data dump 3668
# go go data dump 3669
# go go data dump 3670
# go go data dump 3671
# go go data dump 3672
# go go data dump 3673
# go go data dump 3674
# go go data dump 3675
# go go data dump 3676
# go go data dump 3677
# go go data dump 3678
# go go data dump 3679
# go go data dump 3680
# go go data dump 3681
# go go data dump 3682
# go go data dump 3683
# go go data dump 3684
# go go data dump 3685
# go go data dump 3686
# go go data dump 3687
# go go data dump 3688
# go go data dump 3689
# go go data dump 3690
# go go data dump 3691
# go go data dump 3692
# go go data dump 3693
# go go data dump 3694
# go go data dump 3695
# go go data dump 3696
# go go data dump 3697
# go go data dump 3698
# go go data dump 3699
# go go data dump 3700
# go go data dump 3701
# go go data dump 3702
# go go data dump 3703
# go go data dump 3704
# go go data dump 3705
# go go data dump 3706
# go go data dump 3707
# go go data dump 3708
# go go data dump 3709
# go go data dump 3710
# go go data dump 3711
# go go data dump 3712
# go go data dump 3713
# go go data dump 3714
# go go data dump 3715
# go go data dump 3716
# go go data dump 3717
# go go data dump 3718
# go go data dump 3719
# go go data dump 3720
# go go data dump 3721
# go go data dump 3722
# go go data dump 3723
# go go data dump 3724
# go go data dump 3725
# go go data dump 3726
# go go data dump 3727
# go go data dump 3728
# go go data dump 3729
# go go data dump 3730
# go go data dump 3731
# go go data dump 3732
# go go data dump 3733
# go go data dump 3734
# go go data dump 3735
# go go data dump 3736
# go go data dump 3737
# go go data dump 3738
# go go data dump 3739
# go go data dump 3740
# go go data dump 3741
# go go data dump 3742
# go go data dump 3743
# go go data dump 3744
# go go data dump 3745
# go go data dump 3746
# go go data dump 3747
# go go data dump 3748
# go go data dump 3749
# go go data dump 3750
# go go data dump 3751
# go go data dump 3752
# go go data dump 3753
# go go data dump 3754
# go go data dump 3755
# go go data dump 3756
# go go data dump 3757
# go go data dump 3758
# go go data dump 3759
# go go data dump 3760
# go go data dump 3761
# go go data dump 3762
# go go data dump 3763
# go go data dump 3764
# go go data dump 3765
# go go data dump 3766
# go go data dump 3767
# go go data dump 3768
# go go data dump 3769
# go go data dump 3770
# go go data dump 3771
# go go data dump 3772
# go go data dump 3773
# go go data dump 3774
# go go data dump 3775
# go go data dump 3776
# go go data dump 3777
# go go data dump 3778
# go go data dump 3779
# go go data dump 3780
# go go data dump 3781
# go go data dump 3782
# go go data dump 3783
# go go data dump 3784
# go go data dump 3785
# go go data dump 3786
# go go data dump 3787
# go go data dump 3788
# go go data dump 3789
# go go data dump 3790
# go go data dump 3791
# go go data dump 3792
# go go data dump 3793
# go go data dump 3794
# go go data dump 3795
# go go data dump 3796
# go go data dump 3797
# go go data dump 3798
# go go data dump 3799
# go go data dump 3800
# go go data dump 3801
# go go data dump 3802
# go go data dump 3803
# go go data dump 3804
# go go data dump 3805
# go go data dump 3806
# go go data dump 3807
# go go data dump 3808
# go go data dump 3809
# go go data dump 3810
# go go data dump 3811
# go go data dump 3812
# go go data dump 3813
# go go data dump 3814
# go go data dump 3815
# go go data dump 3816
# go go data dump 3817
# go go data dump 3818
# go go data dump 3819
# go go data dump 3820
# go go data dump 3821
# go go data dump 3822
# go go data dump 3823
# go go data dump 3824
# go go data dump 3825
# go go data dump 3826
# go go data dump 3827
# go go data dump 3828
# go go data dump 3829
# go go data dump 3830
# go go data dump 3831
# go go data dump 3832
# go go data dump 3833
# go go data dump 3834
# go go data dump 3835
# go go data dump 3836
# go go data dump 3837
# go go data dump 3838
# go go data dump 3839
# go go data dump 3840
# go go data dump 3841
# go go data dump 3842
# go go data dump 3843
# go go data dump 3844
# go go data dump 3845
# go go data dump 3846
# go go data dump 3847
# go go data dump 3848
# go go data dump 3849
# go go data dump 3850
# go go data dump 3851
# go go data dump 3852
# go go data dump 3853
# go go data dump 3854
# go go data dump 3855
# go go data dump 3856
# go go data dump 3857
# go go data dump 3858
# go go data dump 3859
# go go data dump 3860
# go go data dump 3861
# go go data dump 3862
# go go data dump 3863
# go go data dump 3864
# go go data dump 3865
# go go data dump 3866
# go go data dump 3867
# go go data dump 3868
# go go data dump 3869
# go go data dump 3870
# go go data dump 3871
# go go data dump 3872
# go go data dump 3873
# go go data dump 3874
# go go data dump 3875
# go go data dump 3876
# go go data dump 3877
# go go data dump 3878
# go go data dump 3879
# go go data dump 3880
# go go data dump 3881
# go go data dump 3882
# go go data dump 3883
# go go data dump 3884
# go go data dump 3885
# go go data dump 3886
# go go data dump 3887
# go go data dump 3888
# go go data dump 3889
# go go data dump 3890
# go go data dump 3891
# go go data dump 3892
# go go data dump 3893
# go go data dump 3894
# go go data dump 3895
# go go data dump 3896
# go go data dump 3897
# go go data dump 3898
# go go data dump 3899
# go go data dump 3900
# go go data dump 3901
# go go data dump 3902
# go go data dump 3903
# go go data dump 3904
# go go data dump 3905
# go go data dump 3906
# go go data dump 3907
# go go data dump 3908
# go go data dump 3909
# go go data dump 3910
# go go data dump 3911
# go go data dump 3912
# go go data dump 3913
# go go data dump 3914
# go go data dump 3915
# go go data dump 3916
# go go data dump 3917
# go go data dump 3918
# go go data dump 3919
# go go data dump 3920
# go go data dump 3921
# go go data dump 3922
